# %% [markdown]
# <a href="https://colab.research.google.com/github/devangi2000/Artificial-Intelligence-Algorithms/blob/master/mnist_week15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  tensorflow
# !pip install numpy
# !pip install keras
# !pip install pillow

#Code

#import statements for mnist dataset and layers

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# split the data between train and test sets
 
(x_train, y_train), (x_test, y_test) = mnist.load_data()
 
print(x_train.shape, y_train.shape)
 
num_classes=10
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
#Normalize the data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
 
batch_size = 128
epochs = 10
#Model Configuration
 
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
 
#Model Compilation
 
model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])
 
#Fitting the data to the Model
 
hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")
 
#Saving the Model
 
model.save('mnist.h5')
print("Saving the model as mnist.h5")

#Evaluating the model with the test data

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/10
# 469/469 [==============================] - 37s 10ms/step - loss: 2.2877 - accuracy: 0.1345 - val_loss: 2.2211 - val_accuracy: 0.5222
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 2.2126 - accuracy: 0.3074 - val_loss: 2.1199 - val_accuracy: 0.6831
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 2.1100 - accuracy: 0.4689 - val_loss: 1.9751 - val_accuracy: 0.7510
# Epoch 4/10
# 469/469 [==============================] - 4s 9ms/step - loss: 1.9681 - accuracy: 0.5621 - val_loss: 1.7727 - val_accuracy: 0.7844
# Epoch 5/10
# 469/469 [==============================] - 4s 9ms/step - loss: 1.7754 - accuracy: 0.6140 - val_loss: 1.5200 - val_accuracy: 0.8062
# Epoch 6/10
# ...
